# %% [markdown]
# # Práctica 7: Detección de Objetos

# %%
import torch
import numpy as np
import cv2 as cv
from handperson import HandPerson
from ultralytics import YOLO

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
video = cv.VideoCapture("videos/people2.mp4")

status, img = video.read()
size=(img.shape[1], img.shape[0])

fourcc = cv.VideoWriter_fourcc(*'DIVX')
video_out = cv.VideoWriter('video1.mp4', fourcc, 20.0, size)

tracking = 255*np.ones((img.shape[0], img.shape[1], 3))

model = YOLO('./models/yolo11x-pose.pt')

# %%
person = HandPerson()
coordinate_x = []
coordinate_y = []
pos = 10
t = 0
time = []
i = 0
while status:
    
    # adaptamos la nueva imagen
    orig = img.copy()
    original = img.copy()
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    detections = model(img)

    if i < 1:
        keypoints = detections[0].keypoints
        keypoint = keypoints[5]
        keypoint_coordinates = keypoint.xy[0]
        right_wrists = keypoint_coordinates[10]
        person.add(int(right_wrists[0]), int(right_wrists[1]))
    else:
        keypoints = detections[0].keypoints

        for keypoint in keypoints:
            keypoint_coordinates = keypoint.xy[0]
            right_wrists = keypoint_coordinates[10]
            conf = keypoint.conf[0, 10]
            if conf > 0.2:
                cv.circle(img, (int(right_wrists[0]), int(right_wrists[1])), 5, (0, 255, 0), -1)
                person.calculate_distance(int(right_wrists[0]), int(right_wrists[1]))
    
    time.append(i)

    i += 1
    
    cv.imshow('Tracking', img)
    
    status, img = video.read()
    
    if cv.waitKey(1)==27:
        status = False
    
video.release()
video_out.release()
cv.destroyAllWindows()
# Out:
# 0: 384x640 7 persons, 739.9ms
# Speed: 3.0ms preprocess, 739.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 652.5ms
# Speed: 3.5ms preprocess, 652.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 639.0ms
# Speed: 3.0ms preprocess, 639.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 682.4ms
# Speed: 1.0ms preprocess, 682.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 606.2ms
# Speed: 2.0ms preprocess, 606.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 622.3ms
# Speed: 2.1ms preprocess, 622.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 603.7ms
# Speed: 1.0ms preprocess, 603.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 612.0ms
# Speed: 2.0ms preprocess, 612.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 644.4ms
# Speed: 1.0ms preprocess, 644.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 628.3ms
# Speed: 1.0ms preprocess, 628.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 649.8ms
# Speed: 2.0ms preprocess, 649.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 605.3ms
# Speed: 1.0ms preprocess, 605.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 607.3ms
# Speed: 2.0ms preprocess, 607.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 601.4ms
# Speed: 2.0ms preprocess, 601.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 600.2ms
# Speed: 1.5ms preprocess, 600.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 614.9ms
# Speed: 2.0ms preprocess, 614.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 598.5ms
# Speed: 1.0ms preprocess, 598.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 598.2ms
# Speed: 1.0ms preprocess, 598.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 588.6ms
# Speed: 2.0ms preprocess, 588.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 602.2ms
# Speed: 2.0ms preprocess, 602.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 609.3ms
# Speed: 2.0ms preprocess, 609.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 637.5ms
# Speed: 2.3ms preprocess, 637.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 655.1ms
# Speed: 1.5ms preprocess, 655.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 671.9ms
# Speed: 2.0ms preprocess, 671.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 636.2ms
# Speed: 1.0ms preprocess, 636.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 600.5ms
# Speed: 2.1ms preprocess, 600.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 598.2ms
# Speed: 1.4ms preprocess, 598.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 598.5ms
# Speed: 1.0ms preprocess, 598.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 598.1ms
# Speed: 2.0ms preprocess, 598.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 592.8ms
# Speed: 2.0ms preprocess, 592.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 595.4ms
# Speed: 2.0ms preprocess, 595.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 600.6ms
# Speed: 1.0ms preprocess, 600.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 591.8ms
# Speed: 2.0ms preprocess, 591.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 613.4ms
# Speed: 2.0ms preprocess, 613.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 604.4ms
# Speed: 1.0ms preprocess, 604.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 628.4ms
# Speed: 1.5ms preprocess, 628.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 623.1ms
# Speed: 2.5ms preprocess, 623.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 625.4ms
# Speed: 1.0ms preprocess, 625.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 616.5ms
# Speed: 2.5ms preprocess, 616.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
