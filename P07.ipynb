# %% [markdown]
# # Práctica 7: Detección de Objetos

# %%
import torch
import cv2 as cv
from matplotlib import pyplot as plt
from handperson import HandPerson
from ultralytics import YOLO

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
video = cv.VideoCapture("videos/people2.mp4")
fps = video.get(cv.CAP_PROP_FPS)

status, img = video.read()
size=(img.shape[1], img.shape[0])

fourcc = cv.VideoWriter_fourcc(*'DIVX')
video_out = cv.VideoWriter('videos/video1.mp4', fourcc, 20.0, size)

model = YOLO('./models/yolo11x-pose.pt')

person = HandPerson(fps=fps)
pos_person = 3
i = 0

while status:
    orig = img.copy()
    original = img.copy()
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    detections = model(img)

    if i < 1:
        keypoints = detections[0].keypoints
        keypoint = keypoints[pos_person]
        keypoint_coordinates = keypoint.xy[0]
        right_wrists = keypoint_coordinates[10]
        person.add(int(right_wrists[0]), int(right_wrists[1]))
    else:
        keypoints = detections[0].keypoints

        for keypoint in keypoints:
            keypoint_coordinates = keypoint.xy[0]
            right_wrists = keypoint_coordinates[10]
            conf = keypoint.conf[0, 10]
            if conf > 0.2:
                cv.circle(img, (int(right_wrists[0]), int(right_wrists[1])), 5, (0, 255, 0), -1)
                person.calculate_distance(int(right_wrists[0]), int(right_wrists[1]))
    
    for j in range(1, len(person.x)):
        if person.x[j - 1] is not None and person.x[j] is not None:
            cv.line(img, 
                    (person.x[j - 1], person.y[j - 1]), 
                    (person.x[j], person.y[j]), 
                    (255, 0, 0), 
                    2)
    
    i += 1
    
    cv.imshow('Tracking', img)
    
    status, img = video.read()
    
    if cv.waitKey(1)==27:
        status = False
    
video.release()
video_out.release()
cv.destroyAllWindows()
# Out:
# 0: 384x640 7 persons, 644.9ms
# Speed: 2.0ms preprocess, 644.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 652.2ms
# Speed: 3.0ms preprocess, 652.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 645.6ms
# Speed: 2.0ms preprocess, 645.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 666.0ms
# Speed: 2.0ms preprocess, 666.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 619.4ms
# Speed: 2.0ms preprocess, 619.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 619.4ms
# Speed: 1.0ms preprocess, 619.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 616.3ms
# Speed: 1.0ms preprocess, 616.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 707.5ms
# Speed: 1.0ms preprocess, 707.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 618.9ms
# Speed: 2.0ms preprocess, 618.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 616.3ms
# Speed: 2.0ms preprocess, 616.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 615.0ms
# Speed: 1.0ms preprocess, 615.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 620.5ms
# Speed: 2.0ms preprocess, 620.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 620.4ms
# Speed: 1.0ms preprocess, 620.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 618.6ms
# Speed: 2.0ms preprocess, 618.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 634.6ms
# Speed: 1.0ms preprocess, 634.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 626.9ms
# Speed: 2.0ms preprocess, 626.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1021.8ms
# Speed: 2.3ms preprocess, 1021.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1141.0ms
# Speed: 2.0ms preprocess, 1141.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1151.8ms
# Speed: 2.0ms preprocess, 1151.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1147.3ms
# Speed: 3.0ms preprocess, 1147.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1207.5ms
# Speed: 3.0ms preprocess, 1207.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1142.3ms
# Speed: 3.1ms preprocess, 1142.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1148.6ms
# Speed: 2.0ms preprocess, 1148.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1142.4ms
# Speed: 3.0ms preprocess, 1142.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 
6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 598.6ms
# Speed: 2.0ms preprocess, 598.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 602.7ms
# Speed: 2.2ms preprocess, 602.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 620.9ms
# Speed: 2.3ms preprocess, 620.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 876.0ms
# Speed: 2.0ms preprocess, 876.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 813.2ms
# Speed: 2.1ms preprocess, 813.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 874.4ms
# Speed: 2.0ms preprocess, 874.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 800.6ms
# Speed: 2.2ms preprocess, 800.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 731.4ms
# Speed: 2.7ms preprocess, 731.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 769.9ms
# Speed: 2.0ms preprocess, 769.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 728.2ms
# Speed: 2.0ms preprocess, 728.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 820.9ms
# Speed: 2.5ms preprocess, 820.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 851.3ms
# Speed: 2.0ms preprocess, 851.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 760.7ms
# Speed: 2.4ms preprocess, 760.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 687.9ms
# Speed: 2.3ms preprocess, 687.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 612.8ms
# Speed: 2.2ms preprocess, 612.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 602.7ms
# Speed: 2.3ms preprocess, 602.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 616.6ms
# Speed: 2.0ms preprocess, 616.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 616.8ms
# Speed: 2.2ms preprocess, 616.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 610.1ms
# Speed: 2.0ms preprocess, 610.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 606.4ms
# Speed: 1.2ms preprocess, 606.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 604.8ms
# Speed: 2.1ms preprocess, 604.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 630.3ms
# Speed: 3.4ms preprocess, 630.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 669.6ms
# Speed: 2.0ms preprocess, 669.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 598.5ms
# Speed: 2.3ms preprocess, 598.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 610.8ms
# Speed: 1.0ms preprocess, 610.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 599.8ms
# Speed: 1.0ms preprocess, 599.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 594.1ms
# Speed: 2.0ms preprocess, 594.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 614.8ms
# Speed: 1.1ms preprocess, 614.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 627.2ms
# Speed: 2.6ms preprocess, 627.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 719.9ms
# Speed: 2.2ms preprocess, 719.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 988.8ms
# Speed: 2.0ms preprocess, 988.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 811.4ms
# Speed: 2.0ms preprocess, 811.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 818.4ms
# Speed: 1.8ms preprocess, 818.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 790.7ms
# Speed: 2.0ms preprocess, 790.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 706.9ms
# Speed: 4.0ms preprocess, 706.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 978.5ms
# Speed: 2.0ms preprocess, 978.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 976.2ms
# Speed: 3.0ms preprocess, 976.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 874.5ms
# Speed: 3.0ms preprocess, 874.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 831.1ms
# Speed: 2.0ms preprocess, 831.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Gráficas

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.plot(person.timestamps, person.x, label="x(t)", color="blue")
plt.xlabel("Tiempo (s)")
plt.ylabel("x (pixeles)")
plt.title("Posición x(t)")
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(person.timestamps, person.y, label="y(t)", color="orange")
plt.xlabel("Tiempo (s)")
plt.ylabel("y (pixeles)")
plt.title("Posición y(t)")
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(person.x, person.y, label="Trayectoria", color="purple")
plt.xlabel("x (pixeles)")
plt.ylabel("y (pixeles)")
plt.title("Trayectoria en el plano x-y")
plt.grid()

plt.subplot(2, 2, 4)
if person.velocities:
    plt.plot(person.timestamps[1:], person.velocities, label="v(t)", color="green")
plt.xlabel("Tiempo (s)")
plt.ylabel("Velocidad (pixeles/s)")
plt.title("Velocidad v(t)")
plt.grid()

plt.tight_layout()
plt.show()
